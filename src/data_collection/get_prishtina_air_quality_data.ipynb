# %%
import requests

url = "https://api.openaq.org/v3/locations?countries_id=65&limit=1000"
headers = {"X-API-Key": "a4f714253a2b3b60ff024968b80f3a0581086849f2c523197bffe2043e735d80"}

response = requests.get(url, headers=headers)
data = response.json()

for loc in data["results"]:
    print(
        f"ID: {loc.get('id')} | "
        f"Name: {loc.get('name')} | "
        f"Locality: {loc.get('locality')}"
    )
# Out:
# ID: 2536 | Name: US Diplomatic Post: Pristina | Locality: None
# ID: 7674 | Name: US Diplomatic Post: Pristina | Locality: Pristina
# ID: 7928 | Name: Peje | Locality: Peje
# ID: 7929 | Name: Mitrovice | Locality: Mitrovice
# ID: 7930 | Name: Prizren | Locality: Prizren
# ID: 7931 | Name: AQMS Prishtine - IHMK | Locality: AQMS Prishtine - IHMK
# ID: 7932 | Name: Gjilan | Locality: Gjilan
# ID: 7933 | Name: AQMS Prishtine Rilindje | Locality: AQMS Prishtine Rilindje
# ID: 7934 | Name: Drenas-Municipality | Locality: Drenas-Municipality
# ID: 7935 | Name: AQMS Hani i Elezit | Locality: Podgorica
# ID: 9337 | Name: Pristina | Locality: N/A
# ID: 494935 | Name: AQMS Obiliq | Locality: AQMS Obiliq
# ID: 494936 | Name: Mobile | Locality: Mobile
# ID: 494937 | Name: Brezovica | Locality: Brezovica
# ID: 494938 | Name: Palaj | Locality: Palaj
# ID: 494939 | Name: AQMS Dardhishte | Locality: AQMS Dardhishte
# ID: 494941 | Name: AQMS Peje | Locality: AQMS Peje
# ID: 921111 | Name: Drenas | Locality: Drenas
# ID: 921120 | Name: Gjilan | Locality: Gjilan
# ID: 921159 | Name: Prizren | Locality: Prizren
# ID: 2578981 | Name: Mobile | Locality: Mobile
# ID: 2655991 | Name: AQMS Brezovica | Locality: Brezovica
# ID: 2655992 | Name: AQMS Gjilan | Locality: Podgorica
# ID: 2655993 | Name: AQMS Palaj | Locality: Podgorica
# ID: 2655994 | Name: AQMS Prizren | Locality: AQMS Prizren
# ID: 6232996 | Name: Rruga Abdullah Boyku | Locality: None

# %%
import os
import glob
import pandas as pd

base_folder = r"C:\Users\Festina\Desktop\openaq_prishtina"
locations = [2536, 7674, 7931, 7933, 9337]

for loc in locations:
    print(f"\n========== LOCATION {loc} ==========")
    
    folder = os.path.join(base_folder, str(loc))
    files = glob.glob(os.path.join(folder, "**", "*.csv.gz"), recursive=True)
    
    dfs = []
    
    for file in files:
        try:
            df = pd.read_csv(file, compression="gzip")
            dfs.append(df)
        except:
            pass
    
    if not dfs:
        print("Nuk ka te dhena.")
        continue
    
    df_loc = pd.concat(dfs, ignore_index=True)
    
    if "parameter" in df_loc.columns:
        params = df_loc["parameter"].dropna().unique()
        print(f"Nr i parametrave: {len(params)}")
        print("Parametrat:", params)
    else:
        print("Kolona 'parameter' nuk ekziston")
    
    if "datetime" in df_loc.columns:
        df_loc["datetime"] = pd.to_datetime(df_loc["datetime"], errors="coerce")
        print("Data min:", df_loc["datetime"].min())
        print("Data max:", df_loc["datetime"].max())
    else:
        print("Kolona 'datetime' nuk ekziston")
# Out:
# ========== LOCATION 2536 ==========
# Nr i parametrave: 1
# Parametrat: ['pm25']
# Data min: 2016-04-08 22:00:00+02:00
# Data max: 2016-11-09 17:00:00+01:00
#
# ========== LOCATION 7674 ==========
# C:\Users\Festina\AppData\Local\Temp\ipykernel_15196\3310311784.py:37: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df_loc["datetime"] = pd.to_datetime(df_loc["datetime"], errors="coerce")
# Nr i parametrave: 1
# Parametrat: ['pm25']
# C:\Users\Festina\AppData\Local\Temp\ipykernel_15196\3310311784.py:37: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df_loc["datetime"] = pd.to_datetime(df_loc["datetime"], errors="coerce")
# Data min: 2016-11-09 18:00:00+01:00
# Data max: 2025-03-04 13:00:00+01:00
#
# ========== LOCATION 7931 ==========
# Nr i parametrave: 6
# Parametrat: ['pm10' 'pm25' 'o3' 'co' 'no2' 'so2']
# C:\Users\Festina\AppData\Local\Temp\ipykernel_15196\3310311784.py:37: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df_loc["datetime"] = pd.to_datetime(df_loc["datetime"], errors="coerce")
# Data min: 2019-01-28 22:00:00+01:00
# Data max: 2025-11-27 19:00:00+01:00
#
# ========== LOCATION 7933 ==========
# Nr i parametrave: 6
# Parametrat: ['pm10' 'pm25' 'o3' 'co' 'no2' 'so2']
# C:\Users\Festina\AppData\Local\Temp\ipykernel_15196\3310311784.py:37: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df_loc["datetime"] = pd.to_datetime(df_loc["datetime"], errors="coerce")
# Data min: 2019-01-28 22:00:00+01:00
# Data max: 2025-11-27 19:00:00+01:00
#
# ========== LOCATION 9337 ==========
# Nr i parametrave: 1
# Parametrat: ['pm25']
# Data min: 2020-06-16 16:00:00+02:00
# Data max: 2025-03-25 00:00:00+01:00
# C:\Users\Festina\AppData\Local\Temp\ipykernel_15196\3310311784.py:37: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df_loc["datetime"] = pd.to_datetime(df_loc["datetime"], errors="coerce")

# %%
import os
import glob
import pandas as pd

base_folder = r"C:\Users\Festina\Desktop\openaq_prishtina"
locations = [7931, 7933]

all_dfs = []

for loc in locations:
    folder = os.path.join(base_folder, str(loc))
    files = glob.glob(os.path.join(folder, "**", "*.csv.gz"), recursive=True)

    for file in files:
        filename = os.path.basename(file)

        if any(year in filename for year in ["2023", "2024", "2025", "2026"]):
            try:
                df = pd.read_csv(file, compression="gzip")
                df["location_id"] = loc
                all_dfs.append(df)
                print(f"Loaded: {filename}")
            except Exception as e:
                print(f"Error: {filename}")

final_df = pd.concat(all_dfs, ignore_index=True)

print(final_df.shape)
# Out:
# Loaded: location-7931-20230314.csv.gz
# Loaded: location-7931-20230315.csv.gz
# Loaded: location-7931-20230318.csv.gz
# Loaded: location-7931-20230319.csv.gz
# Loaded: location-7931-20230320.csv.gz
# Loaded: location-7931-20230321.csv.gz
# Loaded: location-7931-20230322.csv.gz
# Loaded: location-7931-20230324.csv.gz
# Loaded: location-7931-20230325.csv.gz
# Loaded: location-7931-20230326.csv.gz
# Loaded: location-7931-20230331.csv.gz
# Loaded: location-7931-20230401.csv.gz
# Loaded: location-7931-20230402.csv.gz
# Loaded: location-7931-20230403.csv.gz
# Loaded: location-7931-20230404.csv.gz
# Loaded: location-7931-20230405.csv.gz
# Loaded: location-7931-20230406.csv.gz
# Loaded: location-7931-20230407.csv.gz
# Loaded: location-7931-20230412.csv.gz
# Loaded: location-7931-20230413.csv.gz
# Loaded: location-7931-20230414.csv.gz
# Loaded: location-7931-20230420.csv.gz
# Loaded: location-7931-20230421.csv.gz
# Loaded: location-7931-20230424.csv.gz
# Loaded: location-7931-20230516.csv.gz
# Loaded: location-7931-20230517.csv.gz
# Loaded: location-7931-20230518.csv.gz
# Loaded: location-7931-20230519.csv.gz
# Loaded: location-7931-20230520.csv.gz
# Loaded: location-7931-20230521.csv.gz
# Loaded: location-7931-20230522.csv.gz
# Loaded: location-7931-20230524.csv.gz
# Loaded: location-7931-20230525.csv.gz
# Loaded: location-7931-20230607.csv.gz
# Loaded: location-7931-20230608.csv.gz
# Loaded: location-7931-20230609.csv.gz
# Loaded: location-7931-20230610.csv.gz
# Loaded: location-7931-20230611.csv.gz
# Loaded: location-7931-20230626.csv.gz
# Loaded: location-7931-20230627.csv.gz
# Loaded: location-7931-20230628.csv.gz
# Loaded: location-7931-20230630.csv.gz
# Loaded: location-7931-20230701.csv.gz
# Loaded: location-7931-20230702.csv.gz
# Loaded: location-7931-20230703.csv.gz
# Loaded: location-7931-20230704.csv.gz
# Loaded: location-7931-20230707.csv.gz
# Loaded: location-7931-20230708.csv.gz
# Loaded: location-7931-20230711.csv.gz
# Loaded: location-7931-20230712.csv.gz
# Loaded: location-7931-20230717.csv.gz
# Loaded: location-7931-20230718.csv.gz
# Loaded: location-7931-20230719.csv.gz
# Loaded: location-7931-20230720.csv.gz
# Loaded: location-7931-20230721.csv.gz
# Loaded: location-7931-20230722.csv.gz
# Loaded: location-7931-20230723.csv.gz
# Loaded: location-7931-20230724.csv.gz
# Loaded: location-7931-20230725.csv.gz
# Loaded: location-7931-20230726.csv.gz
# Loaded: location-7931-20230727.csv.gz
# Loaded: location-7931-20230728.csv.gz
# Loaded: location-7931-20230729.csv.gz
# Loaded: location-7931-20230730.csv.gz
# Loaded: location-7931-20230731.csv.gz
# Loaded: location-7931-20230801.csv.gz
# Loaded: location-7931-20230811.csv.gz
# Loaded: location-7931-20230817.csv.gz
# Loaded: location-7931-20230818.csv.gz
# Loaded: location-7931-20230824.csv.gz
# Loaded: location-7931-20230825.csv.gz
# Loaded: location-7931-20230826.csv.gz
# Loaded: location-7931-20230827.csv.gz
# Loaded: location-7931-20230828.csv.gz
# Loaded: location-7931-20230830.csv.gz
# Loaded: location-7931-20230831.csv.gz
# Loaded: location-7931-20230901.csv.gz
# Loaded: location-7931-20230902.csv.gz
# Loaded: location-7931-20230903.csv.gz
# Loaded: location-7931-20240311.csv.gz
# Loaded: location-7931-20240312.csv.gz
# Loaded: location-7931-20240313.csv.gz
# Loaded: location-7931-20240314.csv.gz
# Loaded: location-7931-20240315.csv.gz
# Loaded: location-7931-20240318.csv.gz
# Loaded: location-7931-20240323.csv.gz
# Loaded: location-7931-20240324.csv.gz
# Loaded: location-7931-20240325.csv.gz
# Loaded: location-7931-20240326.csv.gz
# Loaded: location-7931-20240327.csv.gz
# Loaded: location-7931-20240328.csv.gz
# Loaded: location-7931-20240329.csv.gz
# Loaded: location-7931-20240330.csv.gz
# Loaded: location-7931-20240331.csv.gz
# Loaded: location-7931-20240401.csv.gz
# Loaded: location-7931-20240402.csv.gz
# Loaded: location-7931-20240403.csv.gz
# Loaded: location-7931-20240404.csv.gz
# Loaded: location-7931-20240405.csv.gz
# Loaded: location-7931-20240406.csv.gz
# Loaded: location-7931-20240407.csv.gz
# Loaded: location-7931-20240408.csv.gz
# Loaded: location-7931-20240409.csv.gz
# Loaded: location-7931-20240410.csv.gz
# Loaded: location-7931-20240411.csv.gz
# Loaded: location-7931-20240412.csv.gz
# Loaded: location-7931-20240413.csv.gz
# Loaded: location-7931-20240414.csv.gz
# Loaded: location-7931-20240415.csv.gz
# Loaded: location-7931-20240416.csv.gz
# Loaded: location-7931-20240417.csv.gz
# Loaded: location-7931-20240418.csv.gz
# Loaded: location-7931-20240419.csv.gz
# Loaded: location-7931-20240420.csv.gz
# Loaded: location-7931-20240421.csv.gz
# Loaded: location-7931-20240422.csv.gz
# Loaded: location-7931-20240423.csv.gz
# Loaded: location-7931-20240425.csv.gz
# Loaded: location-7931-20240426.csv.gz
# Loaded: location-7931-20240427.csv.gz
# Loaded: location-7931-20240428.csv.gz
# Loaded: location-7931-20240429.csv.gz
# Loaded: location-7931-20240430.csv.gz
# Loaded: location-7931-20240501.csv.gz
# Loaded: location-7931-20240502.csv.gz
# Loaded: location-7931-20240503.csv.gz
# Loaded: location-7931-20240504.csv.gz
# Loaded: location-7931-20240505.csv.gz
# Loaded: location-7931-20240506.csv.gz
# Loaded: location-7931-20240507.csv.gz
# Loaded: location-7931-20240508.csv.gz
# Loaded: location-7931-20240509.csv.gz
# Loaded: location-7931-20240510.csv.gz
# Loaded: location-7931-20240511.csv.gz
# Loaded: location-7931-20240512.csv.gz
# Loaded: location-7931-20240513.csv.gz
# Loaded: location-7931-20240514.csv.gz
# Loaded: location-7931-20240515.csv.gz
# Loaded: location-7931-20240516.csv.gz
# Loaded: location-7931-20240517.csv.gz
# Loaded: location-7931-20240518.csv.gz
# Loaded: location-7931-20240519.csv.gz
# Loaded: location-7931-20240520.csv.gz
# Loaded: location-7931-20240521.csv.gz
# Loaded: location-7931-20240522.csv.gz
# Loaded: location-7931-20240523.csv.gz
# Loaded: location-7931-20240524.csv.gz
# Loaded: location-7931-20240525.csv.gz
# Loaded: location-7931-20240526.csv.gz
# Loaded: location-7931-20240527.csv.gz
# Loaded: location-7931-20240528.csv.gz
# Loaded: location-7931-20240529.csv.gz
# Loaded: location-7931-20240530.csv.gz
# Loaded: location-7931-20240531.csv.gz
# Loaded: location-7931-20240601.csv.gz
# Loaded: location-7931-20240602.csv.gz
# Loaded: location-7931-20240603.csv.gz
# Loaded: location-7931-20240604.csv.gz
# Loaded: location-7931-20240605.csv.gz
# Loaded: location-7931-20240606.csv.gz
# Loaded: location-7931-20240607.csv.gz
# Loaded: location-7931-20240608.csv.gz
# Loaded: location-7931-20240609.csv.gz
# Loaded: location-7931-20240610.csv.gz
# Loaded: location-7931-20240611.csv.gz
# Loaded: location-7931-20240612.csv.gz
# Loaded: location-7931-20240613.csv.gz
# Loaded: location-7931-20240614.csv.gz
# Loaded: location-7931-20240615.csv.gz
# Loaded: location-7931-20240616.csv.gz
# Loaded: location-7931-20240617.csv.gz
# Loaded: location-7931-20240618.csv.gz
# Loaded: location-7931-20240619.csv.gz
# Loaded: location-7931-20240620.csv.gz
# Loaded: location-7931-20240621.csv.gz
# Loaded: location-7931-20240622.csv.gz
# Loaded: location-7931-20240623.csv.gz
# Loaded: location-7931-20240624.csv.gz
# Loaded: location-7931-20240625.csv.gz
# Loaded: location-7931-20240626.csv.gz
# Loaded: location-7931-20240627.csv.gz
# Loaded: location-7931-20240628.csv.gz
# Loaded: location-7931-20240629.csv.gz
# Loaded: location-7931-20240630.csv.gz
# Loaded: location-7931-20240701.csv.gz
# Loaded: location-7931-20240702.csv.gz
# Loaded: location-7931-20240703.csv.gz
# Loaded: location-7931-20240704.csv.gz
# Loaded: location-7931-20240705.csv.gz
# Loaded: location-7931-20240706.csv.gz
# Loaded: location-7931-20240707.csv.gz
# Loaded: location-7931-20240708.csv.gz
# Loaded: location-7931-20240709.csv.gz
# Loaded: location-7931-20240710.csv.gz
# Loaded: location-7931-20240711.csv.gz
# Loaded: location-7931-20240713.csv.gz
# Loaded: location-7931-20240714.csv.gz
# Loaded: location-7931-20240715.csv.gz
# Loaded: location-7931-20240716.csv.gz
# Loaded: location-7931-20240717.csv.gz
# Loaded: location-7931-20240718.csv.gz
# Loaded: location-7931-20240719.csv.gz
# Loaded: location-7931-20240720.csv.gz
# Loaded: location-7931-20240721.csv.gz
# Loaded: location-7931-20240722.csv.gz
# Loaded: location-7931-20240723.csv.gz
# Loaded: location-7931-20240724.csv.gz
# Loaded: location-7931-20240725.csv.gz
# Loaded: location-7931-20240726.csv.gz
# Loaded: location-7931-20240727.csv.gz
# Loaded: location-7931-20240728.csv.gz
# Loaded: location-7931-20240729.csv.gz
# Loaded: location-7931-20240730.csv.gz
# Loaded: location-7931-20240731.csv.gz
# Loaded: location-7931-20240801.csv.gz
# Loaded: location-7931-20240802.csv.gz
# Loaded: location-7931-20240803.csv.gz
# Loaded: location-7931-20240804.csv.gz
# Loaded: location-7931-20240805.csv.gz
# Loaded: location-7931-20240806.csv.gz
# Loaded: location-7931-20240807.csv.gz
# Loaded: location-7931-20240808.csv.gz
# Loaded: location-7931-20240809.csv.gz
# Loaded: location-7931-20240810.csv.gz
# Loaded: location-7931-20240811.csv.gz
# Loaded: location-7931-20240812.csv.gz
# Loaded: location-7931-20240813.csv.gz
# Loaded: location-7931-20240814.csv.gz
# Loaded: location-7931-20240821.csv.gz
# Loaded: location-7931-20240822.csv.gz
# Loaded: location-7931-20240823.csv.gz
# Loaded: location-7931-20240824.csv.gz
# Loaded: location-7931-20240825.csv.gz
# Loaded: location-7931-20240826.csv.gz
# Loaded: location-7931-20240827.csv.gz
# Loaded: location-7931-20240828.csv.gz
# Loaded: location-7931-20240829.csv.gz
# Loaded: location-7931-20240830.csv.gz
# Loaded: location-7931-20240831.csv.gz
# Loaded: location-7931-20240901.csv.gz
# Loaded: location-7931-20240902.csv.gz
# Loaded: location-7931-20240903.csv.gz
# Loaded: location-7931-20240904.csv.gz
# Loaded: location-7931-20240905.csv.gz
# Loaded: location-7931-20240906.csv.gz
# Loaded: location-7931-20240907.csv.gz
# Loaded: location-7931-20240908.csv.gz
# Loaded: location-7931-20240909.csv.gz
# Loaded: location-7931-20240910.csv.gz
# Loaded: location-7931-20240911.csv.gz
# Loaded: location-7931-20240912.csv.gz
# Loaded: location-7931-20240913.csv.gz
# Loaded: location-7931-20240914.csv.gz
# Loaded: location-7931-20240915.csv.gz
# Loaded: location-7931-20240916.csv.gz
# Loaded: location-7931-20240917.csv.gz
# Loaded: location-7931-20240918.csv.gz
# Loaded: location-7931-20240919.csv.gz
# Loaded: location-7931-20240920.csv.gz
# Loaded: location-7931-20240921.csv.gz
# Loaded: location-7931-20240922.csv.gz
# Loaded: location-7931-20240923.csv.gz
# Loaded: location-7931-20240924.csv.gz
# Loaded: location-7931-20241106.csv.gz
# Loaded: location-7931-20241108.csv.gz
# Loaded: location-7931-20241110.csv.gz
# Loaded: location-7931-20241111.csv.gz
# Loaded: location-7931-20241112.csv.gz
# Loaded: location-7931-20241113.csv.gz
# Loaded: location-7931-20241114.csv.gz
# Loaded: location-7931-20241115.csv.gz
# Loaded: location-7931-20241116.csv.gz
# Loaded: location-7931-20241117.csv.gz
# Loaded: location-7931-20241118.csv.gz
# Loaded: location-7931-20241119.csv.gz
# Loaded: location-7931-20241120.csv.gz
# Loaded: location-7931-20241121.csv.gz
# Loaded: location-7931-20241122.csv.gz
# Loaded: location-7931-20250305.csv.gz
# Loaded: location-7931-20250306.csv.gz
# Loaded: location-7931-20250307.csv.gz
# Loaded: location-7931-20250308.csv.gz
# Loaded: location-7931-20250309.csv.gz
# Loaded: location-7931-20250310.csv.gz
# Loaded: location-7931-20250311.csv.gz
# Loaded: location-7931-20250312.csv.gz
# Loaded: location-7931-20250313.csv.gz
# Loaded: location-7931-20250314.csv.gz
# Loaded: location-7931-20250315.csv.gz
# Loaded: location-7931-20250316.csv.gz
# Loaded: location-7931-20250317.csv.gz
# Loaded: location-7931-20250318.csv.gz
# Loaded: location-7931-20250319.csv.gz
# Loaded: location-7931-20250320.csv.gz
# Loaded: location-7931-20250321.csv.gz
# Loaded: location-7931-20250322.csv.gz
# Loaded: location-7931-20250323.csv.gz
# Loaded: location-7931-20250324.csv.gz
# Loaded: location-7931-20250325.csv.gz
# Loaded: location-7931-20250326.csv.gz
# Loaded: location-7931-20250327.csv.gz
# Loaded: location-7931-20250328.csv.gz
# Loaded: location-7931-20250329.csv.gz
# Loaded: location-7931-20250330.csv.gz
# Loaded: location-7931-20250331.csv.gz
# Loaded: location-7931-20250401.csv.gz
# Loaded: location-7931-20250402.csv.gz
# Loaded: location-7931-20250403.csv.gz
# Loaded: location-7931-20250404.csv.gz
# Loaded: location-7931-20250405.csv.gz
# Loaded: location-7931-20250406.csv.gz
# Loaded: location-7931-20250407.csv.gz
# Loaded: location-7931-20250408.csv.gz
# Loaded: location-7931-20250409.csv.gz
# Loaded: location-7931-20250410.csv.gz
# Loaded: location-7931-20250411.csv.gz
# Loaded: location-7931-20250412.csv.gz
# Loaded: location-7931-20250414.csv.gz
# Loaded: location-7931-20250415.csv.gz
# Loaded: location-7931-20250416.csv.gz
# Loaded: location-7931-20250417.csv.gz
# Loaded: location-7931-20250422.csv.gz
# Loaded: location-7931-20250423.csv.gz
# Loaded: location-7931-20250424.csv.gz
# Loaded: location-7931-20250425.csv.gz
# Loaded: location-7931-20250426.csv.gz
# Loaded: location-7931-20250427.csv.gz
# Loaded: location-7931-20250428.csv.gz
# Loaded: location-7931-20250429.csv.gz
# Loaded: location-7931-20250430.csv.gz
# Loaded: location-7931-20250501.csv.gz
# Loaded: location-7931-20250502.csv.gz
# Loaded: location-7931-20250504.csv.gz
# Loaded: location-7931-20250505.csv.gz
# Loaded: location-7931-20250506.csv.gz
# Loaded: location-7931-20250507.csv.gz
# Loaded: location-7931-20250508.csv.gz
# Loaded: location-7931-20250509.csv.gz
# Loaded: location-7931-20250510.csv.gz
# Loaded: location-7931-20250511.csv.gz
# Loaded: location-7931-20250512.csv.gz
# Loaded: location-7931-20250513.csv.gz
# Loaded: location-7931-20250514.csv.gz
# Loaded: location-7931-20250515.csv.gz
# Loaded: location-7931-20250516.csv.gz
# Loaded: location-7931-20250517.csv.gz
# Loaded: location-7931-20250518.csv.gz
# Loaded: location-7931-20250519.csv.gz
# Loaded: location-7931-20250520.csv.gz
# Loaded: location-7931-20250521.csv.gz
# Loaded: location-7931-20250522.csv.gz
# Loaded: location-7931-20250523.csv.gz
# Loaded: location-7931-20250524.csv.gz
# Loaded: location-7931-20250525.csv.gz
# Loaded: location-7931-20250526.csv.gz
# Loaded: location-7931-20250527.csv.gz
# Loaded: location-7931-20250528.csv.gz
# Loaded: location-7931-20250529.csv.gz
# Loaded: location-7931-20250530.csv.gz
# Loaded: location-7931-20250531.csv.gz
# Loaded: location-7931-20250601.csv.gz
# Loaded: location-7931-20250602.csv.gz
# Loaded: location-7931-20250604.csv.gz
# Loaded: location-7931-20250605.csv.gz
# Loaded: location-7931-20250606.csv.gz
# Loaded: location-7931-20250607.csv.gz
# Loaded: location-7931-20250608.csv.gz
# Loaded: location-7931-20250609.csv.gz
# Loaded: location-7931-20250610.csv.gz
# Loaded: location-7931-20250611.csv.gz
# Loaded: location-7931-20250612.csv.gz
# Loaded: location-7931-20250613.csv.gz
# Loaded: location-7931-20250614.csv.gz
# Loaded: location-7931-20250615.csv.gz
# Loaded: location-7931-20250616.csv.gz
# Loaded: location-7931-20250617.csv.gz
# Loaded: location-7931-20250618.csv.gz
# Loaded: location-7931-20250619.csv.gz
# Loaded: location-7931-20250620.csv.gz
# Loaded: location-7931-20250621.csv.gz
# Loaded: location-7931-20250622.csv.gz
# Loaded: location-7931-20250623.csv.gz
# Loaded: location-7931-20250624.csv.gz
# Loaded: location-7931-20250625.csv.gz
# Loaded: location-7931-20250626.csv.gz
# Loaded: location-7931-20250627.csv.gz
# Loaded: location-7931-20250628.csv.gz
# Loaded: location-7931-20250629.csv.gz
# Loaded: location-7931-20250630.csv.gz
# Loaded: location-7931-20250701.csv.gz
# Loaded: location-7931-20250702.csv.gz
# Loaded: location-7931-20250703.csv.gz
# Loaded: location-7931-20250704.csv.gz
# Loaded: location-7931-20250705.csv.gz
# Loaded: location-7931-20250706.csv.gz
# Loaded: location-7931-20250707.csv.gz
# Loaded: location-7931-20250708.csv.gz
# Loaded: location-7931-20250709.csv.gz
# Loaded: location-7931-20250710.csv.gz
# Loaded: location-7931-20250711.csv.gz
# Loaded: location-7931-20250712.csv.gz
# Loaded: location-7931-20250713.csv.gz
# Loaded: location-7931-20250714.csv.gz
# Loaded: location-7931-20250715.csv.gz
# Loaded: location-7931-20250716.csv.gz
# Loaded: location-7931-20250717.csv.gz
# Loaded: location-7931-20250718.csv.gz
# Loaded: location-7931-20250719.csv.gz
# Loaded: location-7931-20250720.csv.gz
# Loaded: location-7931-20250721.csv.gz
# Loaded: location-7931-20250722.csv.gz
# Loaded: location-7931-20250723.csv.gz
# Loaded: location-7931-20250724.csv.gz
# Loaded: location-7931-20250725.csv.gz
# Loaded: location-7931-20250726.csv.gz
# Loaded: location-7931-20250727.csv.gz
# Loaded: location-7931-20250728.csv.gz
# Loaded: location-7931-20250729.csv.gz
# Loaded: location-7931-20250730.csv.gz
# Loaded: location-7931-20250731.csv.gz
# Loaded: location-7931-20250801.csv.gz
# Loaded: location-7931-20250802.csv.gz
# Loaded: location-7931-20250803.csv.gz
# Loaded: location-7931-20250804.csv.gz
# Loaded: location-7931-20250805.csv.gz
# Loaded: location-7931-20250806.csv.gz
# Loaded: location-7931-20250807.csv.gz
# Loaded: location-7931-20250808.csv.gz
# Loaded: location-7931-20250809.csv.gz
# Loaded: location-7931-20250810.csv.gz
# Loaded: location-7931-20250811.csv.gz
# Loaded: location-7931-20250812.csv.gz
# Loaded: location-7931-20250813.csv.gz
# Loaded: location-7931-20250814.csv.gz
# Loaded: location-7931-20250815.csv.gz
# Loaded: location-7931-20250816.csv.gz
# Loaded: location-7931-20250817.csv.gz
# Loaded: location-7931-20250818.csv.gz
# Loaded: location-7931-20250819.csv.gz
# Loaded: location-7931-20250820.csv.gz
# Loaded: location-7931-20250821.csv.gz
# Loaded: location-7931-20250822.csv.gz
# Loaded: location-7931-20250823.csv.gz
# Loaded: location-7931-20250824.csv.gz
# Loaded: location-7931-20250825.csv.gz
# Loaded: location-7931-20250826.csv.gz
# Loaded: location-7931-20250827.csv.gz
# Loaded: location-7931-20250828.csv.gz
# Loaded: location-7931-20250829.csv.gz
# Loaded: location-7931-20250830.csv.gz
# Loaded: location-7931-20250831.csv.gz
# Loaded: location-7931-20250901.csv.gz
# Loaded: location-7931-20250902.csv.gz
# Loaded: location-7931-20250903.csv.gz
# Loaded: location-7931-20250904.csv.gz
# Loaded: location-7931-20250905.csv.gz
# Loaded: location-7931-20250906.csv.gz
# Loaded: location-7931-20250907.csv.gz
# Loaded: location-7931-20250908.csv.gz
# Loaded: location-7931-20250909.csv.gz
# Loaded: location-7931-20250910.csv.gz
# Loaded: location-7931-20250911.csv.gz
# Loaded: location-7931-20250912.csv.gz
# Loaded: location-7931-20250913.csv.gz
# Loaded: location-7931-20250914.csv.gz
# Loaded: location-7931-20250915.csv.gz
# Loaded: location-7931-20250916.csv.gz
# Loaded: location-7931-20250917.csv.gz
# Loaded: location-7931-20250918.csv.gz
# Loaded: location-7931-20250919.csv.gz
# Loaded: location-7931-20250920.csv.gz
# Loaded: location-7931-20250921.csv.gz
# Loaded: location-7931-20250922.csv.gz
# Loaded: location-7931-20250923.csv.gz
# Loaded: location-7931-20250924.csv.gz
# Loaded: location-7931-20250925.csv.gz
# Loaded: location-7931-20250926.csv.gz
# Loaded: location-7931-20250927.csv.gz
# Loaded: location-7931-20250928.csv.gz
# Loaded: location-7931-20250929.csv.gz
# Loaded: location-7931-20250930.csv.gz
# Loaded: location-7931-20251001.csv.gz
# Loaded: location-7931-20251002.csv.gz
# Loaded: location-7931-20251003.csv.gz
# Loaded: location-7931-20251004.csv.gz
# Loaded: location-7931-20251005.csv.gz
# Loaded: location-7931-20251006.csv.gz
# Loaded: location-7931-20251007.csv.gz
# Loaded: location-7931-20251008.csv.gz
# Loaded: location-7931-20251009.csv.gz
# Loaded: location-7931-20251010.csv.gz
# Loaded: location-7931-20251011.csv.gz
# Loaded: location-7931-20251012.csv.gz
# Loaded: location-7931-20251013.csv.gz
# Loaded: location-7931-20251014.csv.gz
# Loaded: location-7931-20251015.csv.gz
# Loaded: location-7931-20251016.csv.gz
# Loaded: location-7931-20251017.csv.gz
# Loaded: location-7931-20251018.csv.gz
# Loaded: location-7931-20251019.csv.gz
# Loaded: location-7931-20251020.csv.gz
# Loaded: location-7931-20251021.csv.gz
# Loaded: location-7931-20251022.csv.gz
# Loaded: location-7931-20251023.csv.gz
# Loaded: location-7931-20251024.csv.gz
# Loaded: location-7931-20251025.csv.gz
# Loaded: location-7931-20251026.csv.gz
# Loaded: location-7931-20251027.csv.gz
# Loaded: location-7931-20251028.csv.gz
# Loaded: location-7931-20251029.csv.gz
# Loaded: location-7931-20251030.csv.gz
# Loaded: location-7931-20251031.csv.gz
# Loaded: location-7931-20251101.csv.gz
# Loaded: location-7931-20251102.csv.gz
# Loaded: location-7931-20251103.csv.gz
# Loaded: location-7931-20251104.csv.gz
# Loaded: location-7931-20251105.csv.gz
# Loaded: location-7931-20251106.csv.gz
# Loaded: location-7931-20251114.csv.gz
# Loaded: location-7931-20251115.csv.gz
# Loaded: location-7931-20251116.csv.gz
# Loaded: location-7931-20251117.csv.gz
# Loaded: location-7931-20251118.csv.gz
# Loaded: location-7931-20251119.csv.gz
# Loaded: location-7931-20251120.csv.gz
# Loaded: location-7931-20251121.csv.gz
# Loaded: location-7931-20251122.csv.gz
# Loaded: location-7931-20251123.csv.gz
# Loaded: location-7931-20251124.csv.gz
# Loaded: location-7931-20251125.csv.gz
# Loaded: location-7931-20251126.csv.gz
# Loaded: location-7931-20251127.csv.gz
# Loaded: location-7933-20230314.csv.gz
# Loaded: location-7933-20230315.csv.gz
# Loaded: location-7933-20230318.csv.gz
# Loaded: location-7933-20230319.csv.gz
# Loaded: location-7933-20230320.csv.gz
# Loaded: location-7933-20230321.csv.gz
# Loaded: location-7933-20230322.csv.gz
# Loaded: location-7933-20230324.csv.gz
# Loaded: location-7933-20230325.csv.gz
# Loaded: location-7933-20230326.csv.gz
# Loaded: location-7933-20230331.csv.gz
# Loaded: location-7933-20230401.csv.gz
# Loaded: location-7933-20230402.csv.gz
# Loaded: location-7933-20230403.csv.gz
# Loaded: location-7933-20230404.csv.gz
# Loaded: location-7933-20230405.csv.gz
# Loaded: location-7933-20230406.csv.gz
# Loaded: location-7933-20230407.csv.gz
# Loaded: location-7933-20230412.csv.gz
# Loaded: location-7933-20230414.csv.gz
# Loaded: location-7933-20230415.csv.gz
# Loaded: location-7933-20230420.csv.gz
# Loaded: location-7933-20230421.csv.gz
# Loaded: location-7933-20230424.csv.gz
# Loaded: location-7933-20230516.csv.gz
# Loaded: location-7933-20230517.csv.gz
# Loaded: location-7933-20230518.csv.gz
# Loaded: location-7933-20230519.csv.gz
# Loaded: location-7933-20230520.csv.gz
# Loaded: location-7933-20230521.csv.gz
# Loaded: location-7933-20230522.csv.gz
# Loaded: location-7933-20230524.csv.gz
# Loaded: location-7933-20230525.csv.gz
# Loaded: location-7933-20230607.csv.gz
# Loaded: location-7933-20230608.csv.gz
# Loaded: location-7933-20230609.csv.gz
# Loaded: location-7933-20230610.csv.gz
# Loaded: location-7933-20230611.csv.gz
# Loaded: location-7933-20230626.csv.gz
# Loaded: location-7933-20230627.csv.gz
# Loaded: location-7933-20230628.csv.gz
# Loaded: location-7933-20230630.csv.gz
# Loaded: location-7933-20230701.csv.gz
# Loaded: location-7933-20230702.csv.gz
# Loaded: location-7933-20230703.csv.gz
# Loaded: location-7933-20230704.csv.gz
# Loaded: location-7933-20230707.csv.gz
# Loaded: location-7933-20230708.csv.gz
# Loaded: location-7933-20230711.csv.gz
# Loaded: location-7933-20230712.csv.gz
# Loaded: location-7933-20230717.csv.gz
# Loaded: location-7933-20230718.csv.gz
# Loaded: location-7933-20230719.csv.gz
# Loaded: location-7933-20230720.csv.gz
# Loaded: location-7933-20230721.csv.gz
# Loaded: location-7933-20230722.csv.gz
# Loaded: location-7933-20230723.csv.gz
# Loaded: location-7933-20230724.csv.gz
# Loaded: location-7933-20230725.csv.gz
# Loaded: location-7933-20230726.csv.gz
# Loaded: location-7933-20230727.csv.gz
# Loaded: location-7933-20230728.csv.gz
# Loaded: location-7933-20230729.csv.gz
# Loaded: location-7933-20230730.csv.gz
# Loaded: location-7933-20230731.csv.gz
# Loaded: location-7933-20230801.csv.gz
# Loaded: location-7933-20230811.csv.gz
# Loaded: location-7933-20230817.csv.gz
# Loaded: location-7933-20230818.csv.gz
# Loaded: location-7933-20230824.csv.gz
# Loaded: location-7933-20230825.csv.gz
# Loaded: location-7933-20230826.csv.gz
# Loaded: location-7933-20230827.csv.gz
# Loaded: location-7933-20230828.csv.gz
# Loaded: location-7933-20230829.csv.gz
# Loaded: location-7933-20230830.csv.gz
# Loaded: location-7933-20230831.csv.gz
# Loaded: location-7933-20230901.csv.gz
# Loaded: location-7933-20230902.csv.gz
# Loaded: location-7933-20230903.csv.gz
# Loaded: location-7933-20240311.csv.gz
# Loaded: location-7933-20240312.csv.gz
# Loaded: location-7933-20240313.csv.gz
# Loaded: location-7933-20240314.csv.gz
# Loaded: location-7933-20240315.csv.gz
# Loaded: location-7933-20240318.csv.gz
# Loaded: location-7933-20240323.csv.gz
# Loaded: location-7933-20240324.csv.gz
# Loaded: location-7933-20240325.csv.gz
# Loaded: location-7933-20240326.csv.gz
# Loaded: location-7933-20240327.csv.gz
# Loaded: location-7933-20240328.csv.gz
# Loaded: location-7933-20240329.csv.gz
# Loaded: location-7933-20240330.csv.gz
# Loaded: location-7933-20240331.csv.gz
# Loaded: location-7933-20240401.csv.gz
# Loaded: location-7933-20240402.csv.gz
# Loaded: location-7933-20240403.csv.gz
# Loaded: location-7933-20240404.csv.gz
# Loaded: location-7933-20240405.csv.gz
# Loaded: location-7933-20240406.csv.gz
# Loaded: location-7933-20240407.csv.gz
# Loaded: location-7933-20240408.csv.gz
# Loaded: location-7933-20240409.csv.gz
# Loaded: location-7933-20240410.csv.gz
# Loaded: location-7933-20240411.csv.gz
# Loaded: location-7933-20240412.csv.gz
# Loaded: location-7933-20240413.csv.gz
# Loaded: location-7933-20240414.csv.gz
# Loaded: location-7933-20240415.csv.gz
# Loaded: location-7933-20240416.csv.gz
# Loaded: location-7933-20240417.csv.gz
# Loaded: location-7933-20240418.csv.gz
# Loaded: location-7933-20240419.csv.gz
# Loaded: location-7933-20240420.csv.gz
# Loaded: location-7933-20240421.csv.gz
# Loaded: location-7933-20240422.csv.gz
# Loaded: location-7933-20240423.csv.gz
# Loaded: location-7933-20240425.csv.gz
# Loaded: location-7933-20240426.csv.gz
# Loaded: location-7933-20240427.csv.gz
# Loaded: location-7933-20240428.csv.gz
# Loaded: location-7933-20240429.csv.gz
# Loaded: location-7933-20240430.csv.gz
# Loaded: location-7933-20240501.csv.gz
# Loaded: location-7933-20240502.csv.gz
# Loaded: location-7933-20240503.csv.gz
# Loaded: location-7933-20240504.csv.gz
# Loaded: location-7933-20240505.csv.gz
# Loaded: location-7933-20240506.csv.gz
# Loaded: location-7933-20240507.csv.gz
# Loaded: location-7933-20240508.csv.gz
# Loaded: location-7933-20240509.csv.gz
# Loaded: location-7933-20240510.csv.gz
# Loaded: location-7933-20240511.csv.gz
# Loaded: location-7933-20240512.csv.gz
# Loaded: location-7933-20240513.csv.gz
# Loaded: location-7933-20240514.csv.gz
# Loaded: location-7933-20240515.csv.gz
# Loaded: location-7933-20240516.csv.gz
# Loaded: location-7933-20240517.csv.gz
# Loaded: location-7933-20240518.csv.gz
# Loaded: location-7933-20240519.csv.gz
# Loaded: location-7933-20240520.csv.gz
# Loaded: location-7933-20240521.csv.gz
# Loaded: location-7933-20240522.csv.gz
# Loaded: location-7933-20240523.csv.gz
# Loaded: location-7933-20240524.csv.gz
# Loaded: location-7933-20240525.csv.gz
# Loaded: location-7933-20240526.csv.gz
# Loaded: location-7933-20240527.csv.gz
# Loaded: location-7933-20240528.csv.gz
# Loaded: location-7933-20240530.csv.gz
# Loaded: location-7933-20240531.csv.gz
# Loaded: location-7933-20240601.csv.gz
# Loaded: location-7933-20240602.csv.gz
# Loaded: location-7933-20240603.csv.gz
# Loaded: location-7933-20240604.csv.gz
# Loaded: location-7933-20240605.csv.gz
# Loaded: location-7933-20240606.csv.gz
# Loaded: location-7933-20240607.csv.gz
# Loaded: location-7933-20240608.csv.gz
# Loaded: location-7933-20240609.csv.gz
# Loaded: location-7933-20240610.csv.gz
# Loaded: location-7933-20240611.csv.gz
# Loaded: location-7933-20240612.csv.gz
# Loaded: location-7933-20240613.csv.gz
# Loaded: location-7933-20240614.csv.gz
# Loaded: location-7933-20240615.csv.gz
# Loaded: location-7933-20240616.csv.gz
# Loaded: location-7933-20240617.csv.gz
# Loaded: location-7933-20240618.csv.gz
# Loaded: location-7933-20240619.csv.gz
# Loaded: location-7933-20240620.csv.gz
# Loaded: location-7933-20240621.csv.gz
# Loaded: location-7933-20240622.csv.gz
# Loaded: location-7933-20240623.csv.gz
# Loaded: location-7933-20240624.csv.gz
# Loaded: location-7933-20240625.csv.gz
# Loaded: location-7933-20240626.csv.gz
# Loaded: location-7933-20240627.csv.gz
# Loaded: location-7933-20240628.csv.gz
# Loaded: location-7933-20240629.csv.gz
# Loaded: location-7933-20240630.csv.gz
# Loaded: location-7933-20240701.csv.gz
# Loaded: location-7933-20240702.csv.gz
# Loaded: location-7933-20240703.csv.gz
# Loaded: location-7933-20240704.csv.gz
# Loaded: location-7933-20240705.csv.gz
# Loaded: location-7933-20240706.csv.gz
# Loaded: location-7933-20240707.csv.gz
# Loaded: location-7933-20240708.csv.gz
# Loaded: location-7933-20240709.csv.gz
# Loaded: location-7933-20240710.csv.gz
# Loaded: location-7933-20240711.csv.gz
# Loaded: location-7933-20240712.csv.gz
# Loaded: location-7933-20240713.csv.gz
# Loaded: location-7933-20240714.csv.gz
# Loaded: location-7933-20240715.csv.gz
# Loaded: location-7933-20240716.csv.gz
# Loaded: location-7933-20240717.csv.gz
# Loaded: location-7933-20240718.csv.gz
# Loaded: location-7933-20240719.csv.gz
# Loaded: location-7933-20240720.csv.gz
# Loaded: location-7933-20240721.csv.gz
# Loaded: location-7933-20240722.csv.gz
# Loaded: location-7933-20240723.csv.gz
# Loaded: location-7933-20240724.csv.gz
# Loaded: location-7933-20240725.csv.gz
# Loaded: location-7933-20240726.csv.gz
# Loaded: location-7933-20240727.csv.gz
# Loaded: location-7933-20240728.csv.gz
# Loaded: location-7933-20240729.csv.gz
# Loaded: location-7933-20240730.csv.gz
# Loaded: location-7933-20240731.csv.gz
# Loaded: location-7933-20240801.csv.gz
# Loaded: location-7933-20240802.csv.gz
# Loaded: location-7933-20240803.csv.gz
# Loaded: location-7933-20240804.csv.gz
# Loaded: location-7933-20240805.csv.gz
# Loaded: location-7933-20240806.csv.gz
# Loaded: location-7933-20240807.csv.gz
# Loaded: location-7933-20240808.csv.gz
# Loaded: location-7933-20240809.csv.gz
# Loaded: location-7933-20240810.csv.gz
# Loaded: location-7933-20240811.csv.gz
# Loaded: location-7933-20240812.csv.gz
# Loaded: location-7933-20240813.csv.gz
# Loaded: location-7933-20240814.csv.gz
# Loaded: location-7933-20240821.csv.gz
# Loaded: location-7933-20240822.csv.gz
# Loaded: location-7933-20240823.csv.gz
# Loaded: location-7933-20240824.csv.gz
# Loaded: location-7933-20240825.csv.gz
# Loaded: location-7933-20240826.csv.gz
# Loaded: location-7933-20240827.csv.gz
# Loaded: location-7933-20240828.csv.gz
# Loaded: location-7933-20240829.csv.gz
# Loaded: location-7933-20240830.csv.gz
# Loaded: location-7933-20240831.csv.gz
# Loaded: location-7933-20240901.csv.gz
# Loaded: location-7933-20240902.csv.gz
# Loaded: location-7933-20240903.csv.gz
# Loaded: location-7933-20240904.csv.gz
# Loaded: location-7933-20240905.csv.gz
# Loaded: location-7933-20240906.csv.gz
# Loaded: location-7933-20240907.csv.gz
# Loaded: location-7933-20240908.csv.gz
# Loaded: location-7933-20240909.csv.gz
# Loaded: location-7933-20240910.csv.gz
# Loaded: location-7933-20240911.csv.gz
# Loaded: location-7933-20240912.csv.gz
# Loaded: location-7933-20240913.csv.gz
# Loaded: location-7933-20240914.csv.gz
# Loaded: location-7933-20240915.csv.gz
# Loaded: location-7933-20240916.csv.gz
# Loaded: location-7933-20240917.csv.gz
# Loaded: location-7933-20240918.csv.gz
# Loaded: location-7933-20240919.csv.gz
# Loaded: location-7933-20240920.csv.gz
# Loaded: location-7933-20240921.csv.gz
# Loaded: location-7933-20240922.csv.gz
# Loaded: location-7933-20240923.csv.gz
# Loaded: location-7933-20240924.csv.gz
# Loaded: location-7933-20241106.csv.gz
# Loaded: location-7933-20241107.csv.gz
# Loaded: location-7933-20241108.csv.gz
# Loaded: location-7933-20241109.csv.gz
# Loaded: location-7933-20241110.csv.gz
# Loaded: location-7933-20241111.csv.gz
# Loaded: location-7933-20241112.csv.gz
# Loaded: location-7933-20241113.csv.gz
# Loaded: location-7933-20241114.csv.gz
# Loaded: location-7933-20241115.csv.gz
# Loaded: location-7933-20241116.csv.gz
# Loaded: location-7933-20241117.csv.gz
# Loaded: location-7933-20241118.csv.gz
# Loaded: location-7933-20241119.csv.gz
# Loaded: location-7933-20241120.csv.gz
# Loaded: location-7933-20241121.csv.gz
# Loaded: location-7933-20241122.csv.gz
# Loaded: location-7933-20250305.csv.gz
# Loaded: location-7933-20250306.csv.gz
# Loaded: location-7933-20250307.csv.gz
# Loaded: location-7933-20250308.csv.gz
# Loaded: location-7933-20250309.csv.gz
# Loaded: location-7933-20250310.csv.gz
# Loaded: location-7933-20250311.csv.gz
# Loaded: location-7933-20250312.csv.gz
# Loaded: location-7933-20250313.csv.gz
# Loaded: location-7933-20250314.csv.gz
# Loaded: location-7933-20250315.csv.gz
# Loaded: location-7933-20250316.csv.gz
# Loaded: location-7933-20250317.csv.gz
# Loaded: location-7933-20250318.csv.gz
# Loaded: location-7933-20250319.csv.gz
# Loaded: location-7933-20250320.csv.gz
# Loaded: location-7933-20250321.csv.gz
# Loaded: location-7933-20250322.csv.gz
# Loaded: location-7933-20250323.csv.gz
# Loaded: location-7933-20250324.csv.gz
# Loaded: location-7933-20250325.csv.gz
# Loaded: location-7933-20250326.csv.gz
# Loaded: location-7933-20250327.csv.gz
# Loaded: location-7933-20250328.csv.gz
# Loaded: location-7933-20250329.csv.gz
# Loaded: location-7933-20250330.csv.gz
# Loaded: location-7933-20250331.csv.gz
# Loaded: location-7933-20250401.csv.gz
# Loaded: location-7933-20250402.csv.gz
# Loaded: location-7933-20250403.csv.gz
# Loaded: location-7933-20250404.csv.gz
# Loaded: location-7933-20250405.csv.gz
# Loaded: location-7933-20250406.csv.gz
# Loaded: location-7933-20250407.csv.gz
# Loaded: location-7933-20250408.csv.gz
# Loaded: location-7933-20250409.csv.gz
# Loaded: location-7933-20250410.csv.gz
# Loaded: location-7933-20250411.csv.gz
# Loaded: location-7933-20250412.csv.gz
# Loaded: location-7933-20250413.csv.gz
# Loaded: location-7933-20250414.csv.gz
# Loaded: location-7933-20250415.csv.gz
# Loaded: location-7933-20250416.csv.gz
# Loaded: location-7933-20250417.csv.gz
# Loaded: location-7933-20250422.csv.gz
# Loaded: location-7933-20250423.csv.gz
# Loaded: location-7933-20250424.csv.gz
# Loaded: location-7933-20250425.csv.gz
# Loaded: location-7933-20250426.csv.gz
# Loaded: location-7933-20250427.csv.gz
# Loaded: location-7933-20250428.csv.gz
# Loaded: location-7933-20250429.csv.gz
# Loaded: location-7933-20250430.csv.gz
# Loaded: location-7933-20250501.csv.gz
# Loaded: location-7933-20250502.csv.gz
# Loaded: location-7933-20250504.csv.gz
# Loaded: location-7933-20250505.csv.gz
# Loaded: location-7933-20250506.csv.gz
# Loaded: location-7933-20250507.csv.gz
# Loaded: location-7933-20250508.csv.gz
# Loaded: location-7933-20250509.csv.gz
# Loaded: location-7933-20250510.csv.gz
# Loaded: location-7933-20250511.csv.gz
# Loaded: location-7933-20250512.csv.gz
# Loaded: location-7933-20250513.csv.gz
# Loaded: location-7933-20250514.csv.gz
# Loaded: location-7933-20250515.csv.gz
# Loaded: location-7933-20250516.csv.gz
# Loaded: location-7933-20250517.csv.gz
# Loaded: location-7933-20250518.csv.gz
# Loaded: location-7933-20250519.csv.gz
# Loaded: location-7933-20250520.csv.gz
# Loaded: location-7933-20250521.csv.gz
# Loaded: location-7933-20250522.csv.gz
# Loaded: location-7933-20250523.csv.gz
# Loaded: location-7933-20250524.csv.gz
# Loaded: location-7933-20250525.csv.gz
# Loaded: location-7933-20250526.csv.gz
# Loaded: location-7933-20250527.csv.gz
# Loaded: location-7933-20250528.csv.gz
# Loaded: location-7933-20250529.csv.gz
# Loaded: location-7933-20250530.csv.gz
# Loaded: location-7933-20250531.csv.gz
# Loaded: location-7933-20250601.csv.gz
# Loaded: location-7933-20250602.csv.gz
# Loaded: location-7933-20250604.csv.gz
# Loaded: location-7933-20250605.csv.gz
# Loaded: location-7933-20250606.csv.gz
# Loaded: location-7933-20250607.csv.gz
# Loaded: location-7933-20250608.csv.gz
# Loaded: location-7933-20250609.csv.gz
# Loaded: location-7933-20250610.csv.gz
# Loaded: location-7933-20250611.csv.gz
# Loaded: location-7933-20250612.csv.gz
# Loaded: location-7933-20250613.csv.gz
# Loaded: location-7933-20250614.csv.gz
# Loaded: location-7933-20250615.csv.gz
# Loaded: location-7933-20250616.csv.gz
# Loaded: location-7933-20250617.csv.gz
# Loaded: location-7933-20250618.csv.gz
# Loaded: location-7933-20250619.csv.gz
# Loaded: location-7933-20250620.csv.gz
# Loaded: location-7933-20250621.csv.gz
# Loaded: location-7933-20250622.csv.gz
# Loaded: location-7933-20250623.csv.gz
# Loaded: location-7933-20250624.csv.gz
# Loaded: location-7933-20250625.csv.gz
# Loaded: location-7933-20250626.csv.gz
# Loaded: location-7933-20250627.csv.gz
# Loaded: location-7933-20250628.csv.gz
# Loaded: location-7933-20250629.csv.gz
# Loaded: location-7933-20250630.csv.gz
# Loaded: location-7933-20250701.csv.gz
# Loaded: location-7933-20250702.csv.gz
# Loaded: location-7933-20250703.csv.gz
# Loaded: location-7933-20250704.csv.gz
# Loaded: location-7933-20250705.csv.gz
# Loaded: location-7933-20250706.csv.gz
# Loaded: location-7933-20250707.csv.gz
# Loaded: location-7933-20250708.csv.gz
# Loaded: location-7933-20250709.csv.gz
# Loaded: location-7933-20250710.csv.gz
# Loaded: location-7933-20250711.csv.gz
# Loaded: location-7933-20250712.csv.gz
# Loaded: location-7933-20250713.csv.gz
# Loaded: location-7933-20250714.csv.gz
# Loaded: location-7933-20250715.csv.gz
# Loaded: location-7933-20250716.csv.gz
# Loaded: location-7933-20250717.csv.gz
# Loaded: location-7933-20250718.csv.gz
# Loaded: location-7933-20250719.csv.gz
# Loaded: location-7933-20250720.csv.gz
# Loaded: location-7933-20250721.csv.gz
# Loaded: location-7933-20250722.csv.gz
# Loaded: location-7933-20250723.csv.gz
# Loaded: location-7933-20250724.csv.gz
# Loaded: location-7933-20250725.csv.gz
# Loaded: location-7933-20250726.csv.gz
# Loaded: location-7933-20250727.csv.gz
# Loaded: location-7933-20250728.csv.gz
# Loaded: location-7933-20250729.csv.gz
# Loaded: location-7933-20250730.csv.gz
# Loaded: location-7933-20250731.csv.gz
# Loaded: location-7933-20250801.csv.gz
# Loaded: location-7933-20250802.csv.gz
# Loaded: location-7933-20250803.csv.gz
# Loaded: location-7933-20250804.csv.gz
# Loaded: location-7933-20250805.csv.gz
# Loaded: location-7933-20250806.csv.gz
# Loaded: location-7933-20250807.csv.gz
# Loaded: location-7933-20250808.csv.gz
# Loaded: location-7933-20250809.csv.gz
# Loaded: location-7933-20250810.csv.gz
# Loaded: location-7933-20250811.csv.gz
# Loaded: location-7933-20250812.csv.gz
# Loaded: location-7933-20250813.csv.gz
# Loaded: location-7933-20250814.csv.gz
# Loaded: location-7933-20250815.csv.gz
# Loaded: location-7933-20250816.csv.gz
# Loaded: location-7933-20250817.csv.gz
# Loaded: location-7933-20250818.csv.gz
# Loaded: location-7933-20250819.csv.gz
# Loaded: location-7933-20250820.csv.gz
# Loaded: location-7933-20250821.csv.gz
# Loaded: location-7933-20250822.csv.gz
# Loaded: location-7933-20250823.csv.gz
# Loaded: location-7933-20250824.csv.gz
# Loaded: location-7933-20250825.csv.gz
# Loaded: location-7933-20250826.csv.gz
# Loaded: location-7933-20250827.csv.gz
# Loaded: location-7933-20250828.csv.gz
# Loaded: location-7933-20250829.csv.gz
# Loaded: location-7933-20250830.csv.gz
# Loaded: location-7933-20250831.csv.gz
# Loaded: location-7933-20250901.csv.gz
# Loaded: location-7933-20250902.csv.gz
# Loaded: location-7933-20250903.csv.gz
# Loaded: location-7933-20250904.csv.gz
# Loaded: location-7933-20250905.csv.gz
# Loaded: location-7933-20250906.csv.gz
# Loaded: location-7933-20250907.csv.gz
# Loaded: location-7933-20250908.csv.gz
# Loaded: location-7933-20250909.csv.gz
# Loaded: location-7933-20250910.csv.gz
# Loaded: location-7933-20250911.csv.gz
# Loaded: location-7933-20250912.csv.gz
# Loaded: location-7933-20250913.csv.gz
# Loaded: location-7933-20250914.csv.gz
# Loaded: location-7933-20250915.csv.gz
# Loaded: location-7933-20250916.csv.gz
# Loaded: location-7933-20250917.csv.gz
# Loaded: location-7933-20250918.csv.gz
# Loaded: location-7933-20250919.csv.gz
# Loaded: location-7933-20250920.csv.gz
# Loaded: location-7933-20250921.csv.gz
# Loaded: location-7933-20250922.csv.gz
# Loaded: location-7933-20250923.csv.gz
# Loaded: location-7933-20250924.csv.gz
# Loaded: location-7933-20250925.csv.gz
# Loaded: location-7933-20250926.csv.gz
# Loaded: location-7933-20250927.csv.gz
# Loaded: location-7933-20250928.csv.gz
# Loaded: location-7933-20250929.csv.gz
# Loaded: location-7933-20250930.csv.gz
# Loaded: location-7933-20251001.csv.gz
# Loaded: location-7933-20251002.csv.gz
# Loaded: location-7933-20251003.csv.gz
# Loaded: location-7933-20251004.csv.gz
# Loaded: location-7933-20251005.csv.gz
# Loaded: location-7933-20251006.csv.gz
# Loaded: location-7933-20251007.csv.gz
# Loaded: location-7933-20251008.csv.gz
# Loaded: location-7933-20251009.csv.gz
# Loaded: location-7933-20251010.csv.gz
# Loaded: location-7933-20251011.csv.gz
# Loaded: location-7933-20251012.csv.gz
# Loaded: location-7933-20251013.csv.gz
# Loaded: location-7933-20251014.csv.gz
# Loaded: location-7933-20251015.csv.gz
# Loaded: location-7933-20251016.csv.gz
# Loaded: location-7933-20251017.csv.gz
# Loaded: location-7933-20251018.csv.gz
# Loaded: location-7933-20251019.csv.gz
# Loaded: location-7933-20251020.csv.gz
# Loaded: location-7933-20251021.csv.gz
# Loaded: location-7933-20251022.csv.gz
# Loaded: location-7933-20251023.csv.gz
# Loaded: location-7933-20251024.csv.gz
# Loaded: location-7933-20251025.csv.gz
# Loaded: location-7933-20251026.csv.gz
# Loaded: location-7933-20251027.csv.gz
# Loaded: location-7933-20251028.csv.gz
# Loaded: location-7933-20251029.csv.gz
# Loaded: location-7933-20251030.csv.gz
# Loaded: location-7933-20251031.csv.gz
# Loaded: location-7933-20251101.csv.gz
# Loaded: location-7933-20251102.csv.gz
# Loaded: location-7933-20251103.csv.gz
# Loaded: location-7933-20251104.csv.gz
# Loaded: location-7933-20251105.csv.gz
# Loaded: location-7933-20251106.csv.gz
# Loaded: location-7933-20251107.csv.gz
# Loaded: location-7933-20251108.csv.gz
# Loaded: location-7933-20251109.csv.gz
# Loaded: location-7933-20251110.csv.gz
# Loaded: location-7933-20251111.csv.gz
# Loaded: location-7933-20251112.csv.gz
# Loaded: location-7933-20251113.csv.gz
# Loaded: location-7933-20251114.csv.gz
# Loaded: location-7933-20251115.csv.gz
# Loaded: location-7933-20251116.csv.gz
# Loaded: location-7933-20251117.csv.gz
# Loaded: location-7933-20251118.csv.gz
# Loaded: location-7933-20251119.csv.gz
# Loaded: location-7933-20251120.csv.gz
# Loaded: location-7933-20251121.csv.gz
# Loaded: location-7933-20251122.csv.gz
# Loaded: location-7933-20251123.csv.gz
# Loaded: location-7933-20251124.csv.gz
# Loaded: location-7933-20251125.csv.gz
# Loaded: location-7933-20251126.csv.gz
# Loaded: location-7933-20251127.csv.gz
# (100259, 9)

# %%
df = final_df[final_df["location_id"].isin([7931, 7933])].copy()

df["datetime"] = pd.to_datetime(df["datetime"], errors="coerce", utc=True)

df_avg = (
    df.groupby(["datetime", "parameter"])["value"]
    .mean()
    .reset_index()
)

print(df_avg.head())
# Out:
#                    datetime parameter  value
# 0 2023-03-14 00:00:00+00:00        co   1.70
# 1 2023-03-14 00:00:00+00:00       no2  33.40
# 2 2023-03-14 00:00:00+00:00        o3   6.25
# 3 2023-03-14 00:00:00+00:00      pm10  60.15
# 4 2023-03-14 00:00:00+00:00      pm25  43.65

# %%
df_pivot = df_avg.pivot(index="datetime", columns="parameter", values="value").reset_index()

df_pivot = df_pivot.sort_values("datetime")

output_path = r"C:\Users\Festina\Desktop\openaq_prishtina\prishtina_air_quality_2023_2025.csv"
df_pivot.to_csv(output_path, index=False)

print(df_pivot.head())
print(df_pivot.shape)
print(output_path)
# Out:
# parameter                  datetime    co    no2     o3   pm10   pm25   so2
# 0         2023-03-14 00:00:00+00:00  1.70  33.40   6.25  60.15  43.65  8.45
# 1         2023-03-14 01:00:00+00:00  1.05  29.35  10.45  49.20  37.30  7.70
# 2         2023-03-14 02:00:00+00:00  1.10  26.40  10.95  50.45  39.00  5.95
# 3         2023-03-14 03:00:00+00:00  1.00  23.35  15.05  33.25  27.10  5.90
# 4         2023-03-14 04:00:00+00:00  0.90  21.80  12.00  31.85  26.90  5.50
# (10147, 7)
# C:\Users\Festina\Desktop\openaq_prishtina\prishtina_air_quality_2023_2025.csv
